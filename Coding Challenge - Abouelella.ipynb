# %% [markdown]
# ## Question 1:

# %% [markdown]
# In a video game, a meteor will fall toward the main character's home planet.<br>
# Given the meteor's trajectory as a string in the form y = mx + b and the character's position as a tuple of (x, y),<br>
# return True if the meteor will hit the character and False if it will not.<br>
#
#  - **Examples**<br>
#    will_hit("y = 2x - 5", (0, 0)) ➞ False<br>
#    will_hit("y = -4x + 6", (1, 2)) ➞ True<br>
#    will_hit("y = 2x + 6", (3, 2)) ➞ False<br>
#
# - **Notes**<br>
#   The b value will never be zero or blank.<br>
#   The m value will always be an integer.<br>
#   If the m value is 1, the "1" will be shown.<br>
#   For example, "y = x + 5" will be shown as "y = 1x + 5".<br>
#   If the m value is -1, the "-1" will be shown.<br>
#   For example, "y = -x + 2" will be shown as "y = -1x + 2".<br>

# %% [markdown]
# ## Solution:

# %%
def sign(string: "String"):
    
    # Case m or b have negative value
    if(string[0] == '-' and len(string) == 2):
        return -1 * int(string[1])

    # Case b has positive value
    if(string[0] == '+' and len(string) == 2):
        return int(string[1])
    
    # Case there is no sign attached
    return int(string[0])


def will_hit(trajectory: "equation"="y = 2x - 5", position: tuple=(0, 0)):
    
    # Splitting equation into 2 parts the get right handside then splitting again to separate m and b
    RHS = trajectory.split(' = ')[1]
    RHS = RHS.split(' ', 1)
    
    # Assigning m with its side of the string, removing x char from string, checking sign then converting to int
    m = RHS[0][:-1]
    m = sign(m)
    
    # Assigning b to its side of the string, removing white space, checking sign then converting to int
    b = RHS[1].replace(" ", "")
    b = sign(b)
    
    # splitting tuple to separate variable for easir access
    x, y = position[0], position[1]
    
    # Calculating whether the poistion lies on the fiven trajectory equation then returning boolean 
    hit = (m*x+b == y) 
    
    return hit

# %%
will_hit('y = -1x + 2', (3, 2))
# Out:
# False

# %% [markdown]
# ## Question 2

# %% [markdown]
# Based on object oriented programming concepts create an object model of a chicken (bird).

# %% [markdown]
# ## Solution:

# %%
class Bird():
    def __init__(self, feather_colour, beak_colour):
        self.feather_colour = feather_colour
        self.beak_colour = beak_colour
        # Encapsulation
        self._sing = "KAaaaa"
        
    def name(self):
        print("Bird")
        
    @property
    def sing(self):
        return self._sing
    
    # Abstraction
    def fly(self):
        ''' data '''
        
class Chicken(Bird):
    
    # Inheritance
    def __init__(self, feather_colour, beak_colour, flying):
        super().__init__(feather_colour, beak_colour)
        self.flying = flying

    @property
    def sing(self):
        return super().sing
    
    # Polymorphism
    def name(self):
        print("Chicken")
    
    def fly(self):
        return self.flying

# %%
chicken = Chicken("White", "Yellow", False)
chicken.name()
print(chicken.fly())
print(chicken.sing)
# Out:
# Chicken
# False
# KAaaaa

# %% [markdown]
# ## Question 3

# %% [markdown]
# **About the Data :**
# The data in `Data.csv` consists of normalized process data from a steel mill.<br>
# Each row in the dataset is a coil processed in the steel mill.<br>
#
#
# - **File Data.csv :**
#     - Meta information columns :
#         - "Coil_id"  - ID of the coil.
#         - "Steelgrade" - Type of steelgrade.
#         - "Material spec" - Type of sub material for the steelgrade.
#         - "cgl_production_start" - coil production time.
# - **Target column :**
#     - "mechanical_target_1" - The measured mechanical property measured at the end of the whole process.
# - **Other columns are measured process parameters (we normalized the data to make it anonymous).**
# - **Goal :**
#     - Develop a machine learning model that predicts the  mechanical property("mechanical_target_1") using the measured process parameters.
#     - Explain the black box model.
#
# ### (You will be evaluated based on the approach you take to solve the problem and programming skills)

# %% [markdown]
# ## Solution:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Reading Data from csv file
df = pd.read_csv('Data.csv', index_col='coil_id')
df.drop(df.columns[0], axis=1, inplace=True)
df.head(10)
# Out:
#         steelgrade material_spec cgl_production_start  \
# coil_id
# 1          Grade_0    Material_0          2/9/18 0:59
# 2          Grade_1    Material_1        3/19/18 11:54
# 3          Grade_0    Material_0        3/14/18 18:49
# 4          Grade_0    Material_0          2/2/18 4:25
# 5          Grade_0    Material_0          2/2/18 4:41
# 6          Grade_0    Material_0        1/19/18 18:59
# 7          Grade_0    Material_2         2/2/18 11:44
# 8          Grade_0    Material_2         2/2/18 11:59
# 9          Grade_0    Material_2         2/2/18 12:15
# 10         Grade_0    Material_2         2/2/18 12:32
#
#          hsm_temp_strip_coiling_meas_tail  hsm_temp_strip_exit_fm_meas_tail  \
# coil_id
# 1                                     NaN                               NaN
# 2                                0.828864                          0.944483
# 3                                0.828903                          0.929989
# 4                                0.821872                          0.928737
# 5                                0.829637                          0.928010
# 6                                0.828349                          0.928464
# 7                                0.825572                          0.931917
# 8                                0.819762                          0.932128
# 9                                0.814527                          0.927129
# 10                               0.820807                          0.925844
#
#          ccm_casting_speed_tail  hsm_thickness_reduction_ratio_f1  \
# coil_id
# 1                           NaN                               NaN
# 2                      0.798438                          0.840580
# 3                      0.798438                          0.818035
# 4                      0.851070                          0.595813
# 5                      0.861352                          0.600644
# 6                      0.862500                          0.697262
# 7                      0.690127                          0.695652
# 8                      0.744348                          0.702093
# 9                      0.788522                          0.697262
# 10                     0.798438                          0.682770
#
#          hsm_thickness_reduction_ratio_f5  hsm_cooling_strategy  \
# coil_id
# 1                                     NaN                   NaN
# 2                                0.838791                0.0625
# 3                                0.884131                0.0625
# 4                                0.921914                0.0625
# 5                                0.871537                0.0625
# 6                                0.845088                0.0625
# 7                                0.867758                0.0625
# 8                                0.882872                0.0625
# 9                                0.879093                0.0625
# 10                               0.886650                0.0625
#
#          tcm_deformation_total  ...  cgl_elong_spm_tail  cgl_elong_tl_tail  \
# coil_id                         ...
# 1                     0.903685  ...            0.303654           0.000000
# 2                     0.766175  ...            0.300012           0.000000
# 3                     0.945814  ...            0.306589           0.000000
# 4                          NaN  ...            0.424863           0.234736
# 5                     0.790953  ...            0.413622           0.263496
# 6                     0.923319  ...            0.427701           0.000000
# 7                     0.826691  ...            0.427402           0.271849
# 8                     0.826440  ...            0.422716           0.233502
# 9                     0.826267  ...            0.420789           0.224165
# 10                    0.826188  ...            0.421605           0.106452
#
#          cgl_thick_exit_meas_tail  cgl_wr_force_spm_head  \
# coil_id
# 1                        0.396751               0.382642
# 2                        0.400495               0.209215
# 3                        0.268265               0.393983
# 4                        0.576916               0.262058
# 5                        0.570831               0.281178
# 6                        0.316288               0.378552
# 7                        0.540012               0.478706
# 8                        0.543960               0.475579
# 9                        0.545763               0.476122
# 10                       0.543703               0.464229
#
#          cgl_wr_force_spm_body  cgl_wr_force_spm_tail  \
# coil_id
# 1                     0.407547               0.379913
# 2                     0.199375               0.203155
# 3                     0.337955               0.319281
# 4                     0.292323               0.301225
# 5                     0.304132               0.292848
# 6                     0.351742               0.348914
# 7                     0.454110               0.448843
# 8                     0.460355               0.445401
# 9                     0.458174               0.441442
# 10                    0.457221               0.439262
#
#          cgl_wr_force_spm_spec_head  cgl_wr_force_spm_spec_body  \
# coil_id
# 1                          0.374225                    0.378177
# 2                          0.260019                    0.235105
# 3                          0.484284                    0.394149
# 4                          0.348425                    0.368769
# 5                          0.374319                    0.384150
# 6                          0.498364                    0.439363
# 7                          0.468176                    0.421385
# 8                          0.465117                    0.427180
# 9                          0.465648                    0.425157
# 10                         0.454017                    0.424272
#
#          cgl_wr_force_spm_spec_tail  mechanical_target_1
# coil_id
# 1                          0.337639            49.448726
# 2                          0.229439            36.161856
# 3                          0.356636            45.067861
# 4                          0.363942            45.806417
# 5                          0.354267            45.603351
# 6                          0.417415            48.216325
# 7                          0.398899            51.696909
# 8                          0.395840            48.522078
# 9                          0.392322            48.234379
# 10                         0.390384            48.051661
#
# [10 rows x 45 columns]

# %%
# Raw data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31914 entries, 1 to 31914
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   steelgrade                        31914 non-null  object
#  1   material_spec                     31914 non-null  object
#  2   cgl_production_start              31914 non-null  object
#  3   hsm_temp_strip_coiling_meas_tail  31750 non-null  float64
#  4   hsm_temp_strip_exit_fm_meas_tail  31750 non-null  float64
#  5   ccm_casting_speed_tail            31749 non-null  float64
#  6   hsm_thickness_reduction_ratio_f1  31750 non-null  float64
#  7   hsm_thickness_reduction_ratio_f5  31750 non-null  float64
#  8   hsm_cooling_strategy              31750 non-null  float64
#  9   tcm_deformation_total             29887 non-null  float64
#  10  tund_chem_carbon                  31647 non-null  float64
#  11  tund_chem_aluminium               31647 non-null  float64
#  12  tund_chem_antimony                31647 non-null  float64
#  13  tund_chem_boron                   31647 non-null  float64
#  14  tund_chem_calcium                 31647 non-null  float64
#  15  tund_chem_chromium                31647 non-null  float64
#  16  tund_chem_cobalt                  31647 non-null  float64
#  17  tund_chem_copper                  31647 non-null  float64
#  18  tund_chem_manganese               31647 non-null  float64
#  19  tund_chem_molybdenum              31647 non-null  float64
#  20  tund_chem_niobium                 31485 non-null  float64
#  21  tund_chem_silicon                 31647 non-null  float64
#  22  tund_chem_tin                     31647 non-null  float64
#  23  tund_chem_titanium                31647 non-null  float64
#  24  tund_chem_vanadium                31647 non-null  float64
#  25  tund_chem_nitrogen                31647 non-null  float64
#  26  tund_chem_sulfur                  31647 non-null  float64
#  27  tund_chem_phosphorus              31647 non-null  float64
#  28  cgl_bridle_speed_1_meas_tail      31740 non-null  float64
#  29  cgl_bridle_speed_3_meas_tail      31741 non-null  float64
#  30  cgl_temp_strip_dff_tail           31741 non-null  float64
#  31  cgl_temp_strip_z2_rc_tail         31740 non-null  float64
#  32  cgl_temp_strip_rtf_tail           31741 non-null  float64
#  33  cgl_temp_strip_sc_tail            31720 non-null  float64
#  34  cgl_temp_strip_soak_tail          31741 non-null  float64
#  35  cgl_elong_spm_tail                31753 non-null  float64
#  36  cgl_elong_tl_tail                 31753 non-null  float64
#  37  cgl_thick_exit_meas_tail          31913 non-null  float64
#  38  cgl_wr_force_spm_head             31753 non-null  float64
#  39  cgl_wr_force_spm_body             31753 non-null  float64
#  40  cgl_wr_force_spm_tail             31753 non-null  float64
#  41  cgl_wr_force_spm_spec_head        31753 non-null  float64
#  42  cgl_wr_force_spm_spec_body        31753 non-null  float64
#  43  cgl_wr_force_spm_spec_tail        31753 non-null  float64
#  44  mechanical_target_1               31914 non-null  float64
# dtypes: float64(42), object(3)
# memory usage: 11.2+ MB

# %%
# Cleaning data, removing nan value, removing negative values, rearranging date column
df.dropna(inplace=True)
df = df[(df['cgl_thick_exit_meas_tail']>=0) & (df['cgl_wr_force_spm_head']>=0) & (df['cgl_wr_force_spm_body']>=0) & (df['cgl_wr_force_spm_spec_head']>=0)  & (df['cgl_wr_force_spm_spec_body']>=0)]
df.insert(0, 'cgl_production_start', df.pop('cgl_production_start'))

# %%
# Changing column data types
df['cgl_production_start'] = pd.to_datetime(df['cgl_production_start'], format='%m/%d/%y %H:%M')
df['steelgrade'] = df['steelgrade'].apply(lambda x: float(x[-1]))
df['material_spec'] = df['material_spec'].apply(lambda x: float(x[-1]))

# %%
# Cleaned data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29625 entries, 2 to 31914
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   cgl_production_start              29625 non-null  datetime64[ns]
#  1   steelgrade                        29625 non-null  float64
#  2   material_spec                     29625 non-null  float64
#  3   hsm_temp_strip_coiling_meas_tail  29625 non-null  float64
#  4   hsm_temp_strip_exit_fm_meas_tail  29625 non-null  float64
#  5   ccm_casting_speed_tail            29625 non-null  float64
#  6   hsm_thickness_reduction_ratio_f1  29625 non-null  float64
#  7   hsm_thickness_reduction_ratio_f5  29625 non-null  float64
#  8   hsm_cooling_strategy              29625 non-null  float64
#  9   tcm_deformation_total             29625 non-null  float64
#  10  tund_chem_carbon                  29625 non-null  float64
#  11  tund_chem_aluminium               29625 non-null  float64
#  12  tund_chem_antimony                29625 non-null  float64
#  13  tund_chem_boron                   29625 non-null  float64
#  14  tund_chem_calcium                 29625 non-null  float64
#  15  tund_chem_chromium                29625 non-null  float64
#  16  tund_chem_cobalt                  29625 non-null  float64
#  17  tund_chem_copper                  29625 non-null  float64
#  18  tund_chem_manganese               29625 non-null  float64
#  19  tund_chem_molybdenum              29625 non-null  float64
#  20  tund_chem_niobium                 29625 non-null  float64
#  21  tund_chem_silicon                 29625 non-null  float64
#  22  tund_chem_tin                     29625 non-null  float64
#  23  tund_chem_titanium                29625 non-null  float64
#  24  tund_chem_vanadium                29625 non-null  float64
#  25  tund_chem_nitrogen                29625 non-null  float64
#  26  tund_chem_sulfur                  29625 non-null  float64
#  27  tund_chem_phosphorus              29625 non-null  float64
#  28  cgl_bridle_speed_1_meas_tail      29625 non-null  float64
#  29  cgl_bridle_speed_3_meas_tail      29625 non-null  float64
#  30  cgl_temp_strip_dff_tail           29625 non-null  float64
#  31  cgl_temp_strip_z2_rc_tail         29625 non-null  float64
#  32  cgl_temp_strip_rtf_tail           29625 non-null  float64
#  33  cgl_temp_strip_sc_tail            29625 non-null  float64
#  34  cgl_temp_strip_soak_tail          29625 non-null  float64
#  35  cgl_elong_spm_tail                29625 non-null  float64
#  36  cgl_elong_tl_tail                 29625 non-null  float64
#  37  cgl_thick_exit_meas_tail          29625 non-null  float64
#  38  cgl_wr_force_spm_head             29625 non-null  float64
#  39  cgl_wr_force_spm_body             29625 non-null  float64
#  40  cgl_wr_force_spm_tail             29625 non-null  float64
#  41  cgl_wr_force_spm_spec_head        29625 non-null  float64
#  42  cgl_wr_force_spm_spec_body        29625 non-null  float64
#  43  cgl_wr_force_spm_spec_tail        29625 non-null  float64
#  44  mechanical_target_1               29625 non-null  float64
# dtypes: datetime64[ns](1), float64(44)
# memory usage: 10.4 MB

# %%
df.describe()
# Out:
#          steelgrade  material_spec  hsm_temp_strip_coiling_meas_tail  \
# count  29625.000000   29625.000000                      29625.000000
# mean       0.986937       3.791257                          0.839418
# std        1.529615       3.001199                          0.032651
# min        0.000000       0.000000                          0.667799
# 25%        0.000000       0.000000                          0.820396
# 50%        0.000000       4.000000                          0.828395
# 75%        2.000000       7.000000                          0.857046
# max        9.000000       9.000000                          1.000000
#
#        hsm_temp_strip_exit_fm_meas_tail  ccm_casting_speed_tail  \
# count                      29625.000000            29625.000000
# mean                           0.930502                0.777481
# std                            0.008247                0.070997
# min                            0.872324                0.000000
# 25%                            0.927909                0.735937
# 50%                            0.931279                0.774600
# 75%                            0.934382                0.819103
# max                            1.000000                1.000000
#
#        hsm_thickness_reduction_ratio_f1  hsm_thickness_reduction_ratio_f5  \
# count                      29625.000000                      29625.000000
# mean                           0.712474                          0.869229
# std                            0.077770                          0.043288
# min                            0.563607                          0.715365
# 25%                            0.658615                          0.841310
# 50%                            0.711755                          0.869018
# 75%                            0.768116                          0.897985
# max                            0.988728                          1.000000
#
#        hsm_cooling_strategy  tcm_deformation_total  tund_chem_carbon  ...  \
# count          29625.000000           29625.000000      29625.000000  ...
# mean               0.291808               0.874055          0.352984  ...
# std                0.402518               0.085588          0.323220  ...
# min                0.000000               0.498998          0.006935  ...
# 25%                0.062500               0.792659          0.142874  ...
# 50%                0.062500               0.898596          0.168743  ...
# 75%                0.062500               0.924120          0.783801  ...
# max                1.000000               1.000000          1.000000  ...
#
#        cgl_elong_spm_tail  cgl_elong_tl_tail  cgl_thick_exit_meas_tail  \
# count        29625.000000       29625.000000              29625.000000
# mean             0.208775           0.033964                  0.361446
# std              0.156707           0.069770                  0.157185
# min              0.000000           0.000000                  0.000000
# 25%              0.000000           0.000000                  0.218900
# 50%              0.227609           0.000000                  0.330932
# 75%              0.308379           0.006853                  0.503622
# max              1.000000           1.000000                  1.000000
#
#        cgl_wr_force_spm_head  cgl_wr_force_spm_body  cgl_wr_force_spm_tail  \
# count           29625.000000           29625.000000           29625.000000
# mean                0.255150               0.260227               0.253411
# std                 0.177456               0.164561               0.166219
# min                 0.000000               0.000000               0.000000
# 25%                 0.101341               0.151770               0.124826
# 50%                 0.292483               0.288976               0.277967
# 75%                 0.384531               0.368211               0.362454
# max                 1.000000               0.972326               0.986631
#
#        cgl_wr_force_spm_spec_head  cgl_wr_force_spm_spec_body  \
# count                29625.000000                29625.000000
# mean                     0.231112                    0.224171
# std                      0.159865                    0.140667
# min                      0.000000                    0.000000
# 25%                      0.096037                    0.138505
# 50%                      0.261767                    0.251506
# 75%                      0.344807                    0.313573
# max                      1.000000                    0.893787
#
#        cgl_wr_force_spm_spec_tail  mechanical_target_1
# count                29625.000000         29625.000000
# mean                     0.208352            60.414337
# std                      0.135729            20.935711
# min                      0.000000            16.024396
# 25%                      0.106149            48.357751
# 50%                      0.228914            51.580115
# 75%                      0.293290            63.812811
# max                      0.843042           123.178979
#
# [8 rows x 44 columns]

# %%
# Features
X = df.iloc[:,1:44]

# Target
Y = df[['mechanical_target_1']]

# Splitting data into training and testing portions
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=100)

# %%
# Multiple Regression
LR = LinearRegression()

# Non Negative Least Squares
LR.fit(X_train,y_train)

# Predict using the linear model
y_pred =  LR.predict(X_test)
print (X_test) #test dataset
print (y_pred) #predicted values
# Out:
#          steelgrade  material_spec  hsm_temp_strip_coiling_meas_tail  \
# coil_id
# 26797           0.0            7.0                          0.813022
# 1623            0.0            0.0                          0.829654
# 5346            0.0            2.0                          0.816173
# 7757            0.0            4.0                          0.826565
# 22817           0.0            7.0                          0.812231
# ...             ...            ...                               ...
# 9531            2.0            3.0                          0.878603
# 7771            0.0            4.0                          0.830162
# 9412            2.0            5.0                          0.859817
# 21771           0.0            4.0                          0.818263
# 8630            0.0            0.0                          0.816049
#
#          hsm_temp_strip_exit_fm_meas_tail  ccm_casting_speed_tail  \
# coil_id
# 26797                            0.932869                0.756250
# 1623                             0.926712                0.945312
# 5346                             0.927566                0.831572
# 7757                             0.928147                0.842187
# 22817                            0.921068                0.715625
# ...                                   ...                     ...
# 9531                             0.904732                0.718750
# 7771                             0.930949                0.842187
# 9412                             0.901802                0.756635
# 21771                            0.918887                0.851191
# 8630                             0.930360                0.795312
#
#          hsm_thickness_reduction_ratio_f1  hsm_thickness_reduction_ratio_f5  \
# coil_id
# 26797                            0.626409                          0.831234
# 1623                             0.677939                          0.887909
# 5346                             0.711755                          0.875315
# 7757                             0.819646                          0.863980
# 22817                            0.605475                          0.853904
# ...                                   ...                               ...
# 9531                             0.732689                          0.880353
# 7771                             0.809984                          0.851385
# 9412                             0.705314                          0.881612
# 21771                            0.806763                          0.908060
# 8630                             0.769726                          0.795970
#
#          hsm_cooling_strategy  tcm_deformation_total  tund_chem_carbon  ...  \
# coil_id                                                                 ...
# 26797                  0.0625               0.970485          0.157356  ...
# 1623                   0.0625               0.678329          0.182721  ...
# 5346                   0.0625               0.898149          0.123748  ...
# 7757                   0.0625               0.898901          0.178005  ...
# 22817                  0.0625               0.971298          0.129376  ...
# ...                       ...                    ...               ...  ...
# 9531                   1.0000               0.721076          0.893170  ...
# 7771                   0.0625               0.898629          0.165429  ...
# 9412                   1.0000               0.767141          0.889809  ...
# 21771                  0.0625               0.923019          0.143281  ...
# 8630                   0.0625               0.679607          0.175003  ...
#
#          cgl_temp_strip_soak_tail  cgl_elong_spm_tail  cgl_elong_tl_tail  \
# coil_id
# 26797                    0.711221            0.152905                0.0
# 1623                     0.865865            0.000000                0.0
# 5346                     0.865614            0.305286                0.0
# 7757                     0.879650            0.000000                0.0
# 22817                    0.725368            0.168716                0.0
# ...                           ...                 ...                ...
# 9531                     0.838041            0.000000                0.0
# 7771                     0.885274            0.000000                0.0
# 9412                     0.837899            0.000000                0.0
# 21771                    0.864317            0.430487                0.0
# 8630                     0.850061            0.000000                0.0
#
#          cgl_thick_exit_meas_tail  cgl_wr_force_spm_head  \
# coil_id
# 26797                    0.171182               0.111539
# 1623                     0.627746               0.000029
# 5346                     0.402500               0.413053
# 7757                     0.421733               0.000000
# 22817                    0.170494               0.092365
# ...                           ...                    ...
# 9531                     0.496376               0.000000
# 7771                     0.423983               0.000000
# 9412                     0.496831               0.000000
# 21771                    0.265454               0.353878
# 8630                     0.637974               0.000000
#
#          cgl_wr_force_spm_body  cgl_wr_force_spm_tail  \
# coil_id
# 26797                 0.151857               0.152877
# 1623                  0.000053               0.000254
# 5346                  0.365046               0.353340
# 7757                  0.000000               0.000101
# 22817                 0.234536               0.235560
# ...                        ...                    ...
# 9531                  0.000000               0.000000
# 7771                  0.000000               0.001561
# 9412                  0.000000               0.000000
# 21771                 0.334945               0.329841
# 8630                  0.000000               0.000000
#
#          cgl_wr_force_spm_spec_head  cgl_wr_force_spm_spec_body  \
# coil_id
# 26797                      0.109711                    0.141722
# 1623                       0.000029                    0.000051
# 5346                       0.329811                    0.276558
# 7757                       0.000000                    0.000000
# 22817                      0.075062                    0.180844
# ...                             ...                         ...
# 9531                       0.000000                    0.000000
# 7771                       0.000000                    0.000000
# 9412                       0.000000                    0.000000
# 21771                      0.353868                    0.317790
# 8630                       0.000000                    0.000000
#
#          cgl_wr_force_spm_spec_tail
# coil_id
# 26797                      0.136645
# 1623                       0.000230
# 5346                       0.256378
# 7757                       0.000091
# 22817                      0.173958
# ...                             ...
# 9531                       0.000000
# 7771                       0.001409
# 9412                       0.000000
# 21771                      0.299724
# 8630                       0.000000
#
# [11850 rows x 43 columns]
# [[94.23301007]
#  [46.49234605]
#  [48.89182476]
#  ...
#  [58.81347602]
#  [56.41253985]
#  [49.87571083]]

# %%
# coefficient of determination
score = r2_score(y_test,y_pred)

print('R2 Score = ',score)
print('Mean Squared Error = ',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error = ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score =  0.9360828634526998
# Mean Squared Error =  28.249060215231566
# Root Mean Squared Error =  5.31498449811771
